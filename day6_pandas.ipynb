# %%
import pandas as pd
modf = pd.read_csv('Movie-Data.csv',index_col='Title')
modf
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
r = modf['Revenue (Millions)']

# %%
r
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
rmax = max(r)

# %%
maxi = modf[modf['Revenue (Millions)']==rmax]
maxi
# Out:
#                        Rank                    Genre  \
# Title
# G.I. Joe: Retaliation   879  Action,Adventure,Sci-Fi
#
#                                                              Description  \
# Title
# G.I. Joe: Retaliation  The G.I. Joes are not only fighting their mort...
#
#                                                                 Director  \
# Title
# G.I. Joe: Retaliation   they are forced to contend with threats from ...
#
#                            Actors  \
# Title
# G.I. Joe: Retaliation  Jon M. Chu
#
#                                                                     Year  \
# Title
# G.I. Joe: Retaliation  Dwayne Johnson, Channing Tatum, Adrianne Palic...
#
#                        Runtime (Minutes)  Rating  Votes  Revenue (Millions)  \
# Title
# G.I. Joe: Retaliation               2013   110.0    5.8            152145.0
#
#                        Metascore  Unnamed: 12
# Title
# G.I. Joe: Retaliation     122.51         41.0

# %%
dire = modf[modf['Director']=='Billy Ray']

# %%
dire
# Out:
#                       Rank                Genre  \
# Title
# Secret in Their Eyes   996  Crime,Drama,Mystery
#
#                                                             Description  \
# Title
# Secret in Their Eyes  A tight-knit team of rising investigators, alo...
#
#                        Director  \
# Title
# Secret in Their Eyes  Billy Ray
#
#                                                                  Actors  Year  \
# Title
# Secret in Their Eyes  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
#
#                       Runtime (Minutes)  Rating    Votes  Revenue (Millions)  \
# Title
# Secret in Their Eyes                111     6.2  27585.0                 NaN
#
#                       Metascore  Unnamed: 12
# Title
# Secret in Their Eyes       45.0          NaN

# %%
type(modf['Director'])
# Out:
# pandas.core.series.Series

# %%
for i,y in enumerate(modf['Director']):
    if 'Ridley' in y:
        print(i,y)
# Out:
# 1 Ridley Scott
# 102 Ridley Scott
# 387 Ridley Scott
# 470 Ridley Scott
# 516 Ridley Scott
# 521 Ridley Scott
# 530 Ridley Scott
# 737 Ridley Scott

# %%
twtoet = modf[(modf['Rating']>=0) & (modf['Rating']<=3)]
twtoet
# Out:
#                          Rank                     Genre  \
# Title
# Don't Fuck in the Woods    43                    Horror
# Disaster Movie            830                    Comedy
# Dragonball Evolution      872  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Don't Fuck in the Woods  A group of friends are going on a camping trip...
# Disaster Movie           Over the course of one evening, an unsuspectin...
# Dragonball Evolution     The young warrior Son Goku sets out on a quest...
#
#                                 Director  \
# Title
# Don't Fuck in the Woods    Shawn Burkett
# Disaster Movie           Jason Friedberg
# Dragonball Evolution          James Wong
#
#                                                                     Actors  \
# Title
# Don't Fuck in the Woods  Brittany Blanton, Ayse Howard, Roman Jossart,N...
# Disaster Movie           Carmen Electra, Vanessa Lachey,Nicole Parker, ...
# ...

# %%
modf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                980 non-null    object
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   float64
#  9   Revenue (Millions)  873 non-null    float64
#  10  Metascore           936 non-null    float64
#  11  Unnamed: 12         2 non-null      float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 133.9+ KB

# %%
modf.describe()
# Out:
#               Rank  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000         118.894000     7.025200  1.696136e+05
# std     288.819436         105.692439     5.581096  1.888727e+05
# min       1.000000          66.000000     1.900000  4.800000e+00
# 25%     250.750000         100.000000     6.200000  3.613975e+04
# 50%     500.500000         111.000000     6.800000  1.106315e+05
# 75%     750.250000         123.000000     7.400000  2.399098e+05
# max    1000.000000        2016.000000   118.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore  Unnamed: 12
# count          873.000000  936.000000     2.000000
# mean           305.706896   59.042564    51.500000
# std           5299.021204   17.328207    14.849242
# min              0.000000   11.000000    41.000000
# 25%             13.300000   47.000000    46.250000
# 50%             48.040000   59.500000    51.500000
# ...

# %%
rev25 = modf['Revenue (Millions)']
rev25
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
modf['Revenue (Millions)'].quantile(0.25)
# Out:
# 13.3

# %%
demo = modf[((modf['Votes']>=500) & (modf['Votes']<=100000) & (modf['Rating']>=8) & (modf['Revenue (Millions)']<modf['Revenue (Millions)'].quantile(0.25)))]
demo
# Out:
#                          Rank                    Genre  \
# Title
# Bahubali: The Beginning    27   Action,Adventure,Drama
# Kimi no na wa              97  Animation,Drama,Fantasy
# Dangal                    118   Action,Biography,Drama
# Ah-ga-ssi                 146    Drama,Mystery,Romance
# Forushande                185           Drama,Thriller
# Sing Street               274       Comedy,Drama,Music
# Mommy                     609                    Drama
# Incendies                 714        Drama,Mystery,War
#
#                                                                Description  \
# Title
# Bahubali: The Beginning  In ancient India, an adventurous and daring ma...
# Kimi no na wa            Two strangers find themselves linked in a biza...
# Dangal                   Former wrestler Mahavir Singh Phogat and his t...
# Ah-ga-ssi                A woman is hired as a handmaiden to a Japanese...
# Forushande               While both participating in a production of "D...
# ...

# %%
modf
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...
